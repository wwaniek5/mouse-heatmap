# %%
import plotly
plotly.tools.set_credentials_file(username='wwaniek5', api_key='j5UjXoQ2AyVq0DeqKE7u')

import pandas as pd
import sqlite3
import pprint

conn = sqlite3.connect("MouseHeatmapDb.sqlite")
df = pd.read_sql_query("""select 
X,
Y,
cast(MouseFinishedCount as float) as MouseFinishedCount,
cast(MousePassedCount as float) as MousePassedCount,
cast(SpeedCount as float) as SpeedCount 
from ScreenUnits;""", conn)


conn.close()
df=df.groupby(['X','Y'], as_index=False).sum()
df
# Out:
#          X    Y  MouseFinishedCount  MousePassedCount  SpeedCount
# 0        0    0               204.0             240.0    342547.0
# 1        0    1                51.0              76.0     83509.0
# 2        0    2                75.0             103.0    113836.0
# 3        0    3               169.0             198.0     74466.0
# 4        0    4               152.0             186.0    100134.0
# 5        0    5                95.0             124.0     90751.0
# 6        0    6                69.0              94.0     97243.0
# 7        0    7                67.0              93.0     95938.0
# 8        0    8                64.0              94.0     99960.0
# 9        0    9                58.0              84.0     74185.0
# 10       0   10                44.0              61.0     61340.0
# 11       0   11                51.0              68.0     55510.0
# 12       0   12                28.0              45.0     79679.0
# 13       0   13                35.0              52.0     65003.0
# 14       0   14                29.0              46.0    135444.0
# 15       0   15                17.0              34.0     87964.0
# 16       0   16                11.0              21.0     55544.0
# 17       0   17                 6.0              15.0     34773.0
# 18       0   18                11.0              20.0     28659.0
# 19       0   19                 8.0              16.0     42157.0
# 20       0   20                15.0              23.0     29571.0
# 21       0   21                18.0              28.0     31163.0
# 22       0   22                19.0              29.0     35175.0
# 23       0   23                18.0              27.0     41256.0
# 24       0   24                 8.0              17.0    212956.0
# 25       0   25                10.0              17.0     77514.0
# 26       0   26                 3.0               8.0     20675.0
# 27       0   27                 1.0               4.0      9124.0
# 28       0   28                 1.0               4.0      9149.0
# 29       0   29                 8.0              13.0     32176.0
# ...    ...  ...                 ...               ...         ...
# 34389  336   67                 1.0               4.0     11528.0
# 34390  336   68                 4.0               8.0     17040.0
# 34391  336   69                 0.0               1.0      4637.0
# 34392  336   70                 1.0               2.0      9811.0
# 34393  336   71                 0.0               1.0      5174.0
# 34394  336   72                 0.0               1.0      5174.0
# 34395  336   73                 0.0               1.0      5174.0
# 34396  336   74                 1.0               2.0      9984.0
# 34397  336   75                 0.0               1.0      4810.0
# 34398  336   76                 0.0               1.0      4810.0
# 34399  336   77                 0.0               1.0      4810.0
# 34400  336   78                 1.0               3.0     14648.0
# 34401  336   79                 0.0               1.0      4202.0
# 34402  336   80                 0.0               2.0     12413.0
# 34403  336   81                 1.0               2.0     10753.0
# 34404  336   82                 0.0               1.0      6551.0
# 34405  336   83                 0.0               1.0      6551.0
# 34406  336   84                 2.0               5.0     69826.0
# 34407  336   86                 3.0               4.0      1934.0
# 34408  336   89                 0.0               1.0      9677.0
# 34409  336   91                 1.0               2.0     26037.0
# 34410  336   92                 0.0               1.0     23150.0
# 34411  336   93                 1.0               2.0     25260.0
# 34412  336   94                 0.0               1.0      2110.0
# 34413  336   97                 3.0               4.0      2225.0
# 34414  336   98                 0.0               1.0         5.0
# 34415  336  102                 2.0               5.0      2935.0
# 34416  336  103                 2.0               9.0     19399.0
# 34417  336  104                 5.0               8.0      6042.0
# 34418  336  105                 2.0               7.0      6871.0
#
# [34419 rows x 5 columns]

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np


mouseFinishedCountMatrix= pd.pivot_table(df,values='MouseFinishedCount', index=['Y'],columns=['X'],fill_value =0).values 
mouseFinishedCountMatrix
py.iplot([go.Heatmap(z=np.flipud(mouseFinishedCountMatrix))], filename='mouseFinishedCountHeatmap')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wwaniek5/16.embed" height="525px" width="100%"></iframe>

# %%
MousePassedCountMatrix=pd.pivot_table(df,values='MousePassedCount', index=['Y'],columns=['X'],fill_value =0).values 
py.iplot([go.Heatmap(z=np.flipud(MousePassedCountMatrix))], filename='MousePassedCountHeatmap')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wwaniek5/18.embed" height="525px" width="100%"></iframe>

# %%
py.iplot([go.Heatmap(z=np.flipud(MousePassedCountMatrix-mouseFinishedCountMatrix))], filename='DifferenceHeatmap')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wwaniek5/20.embed" height="525px" width="100%"></iframe>

# %%
SpeedCountMatrix=pd.pivot_table(df,values='SpeedCount', index=['Y'],columns=['X'],fill_value =0).values 
speedMatrix=np.divide(SpeedCountMatrix,MousePassedCountMatrix)
py.iplot([go.Heatmap(z=np.flipud(speedMatrix))], filename='SpeedHeatmap')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wwaniek5/22.embed" height="525px" width="100%"></iframe>
